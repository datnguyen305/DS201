# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/phoner/phoner/test_word.json
# /kaggle/input/phoner/phoner/dev_word.json
# /kaggle/input/phoner/phoner/train_word.json
# /kaggle/input/lab5-dataset/lab5/dev.json
# /kaggle/input/lab5-dataset/lab5/train.json
# /kaggle/input/lab5-dataset/lab5/test.json

# %%
# !git clone https://github.com/datnguyen305/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 570, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 570 (delta 69), reused 90 (delta 40), pack-reused 415 (from 1)
# Receiving objects: 100% (570/570), 68.75 MiB | 38.01 MiB/s, done.
# Resolving deltas: 100% (222/222), done.

# %%
# %cd DS201/BT5
# Out:
# /kaggle/working/DS201/BT5/DS201/BT5

# %%
# !pip install pyvi
# Out:
# Requirement already satisfied: pyvi in /usr/local/lib/python3.12/dist-packages (0.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi) (1.6.1)
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.12/dist-packages (from pyvi) (0.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Requirement already satisfied: python-crfsuite>=0.9.7 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.12)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)

# %%
# !python bai2_main.py
# Out:
# 06:16:59 - INFO - Using device: cpu
# 06:16:59 - INFO - Building Vocabulary...
# Building vocab from: /kaggle/input/phoner/phoner/train_word.json
# File /kaggle/input/phoner/phoner/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Vocab size: 4741
# Num tags: 20
# 06:16:59 - INFO - Vocab Size: 4741
# 06:16:59 - INFO - Tags (20): {'B-AGE': 0, 'B-DATE': 1, 'B-GENDER': 2, 'B-JOB': 3, 'B-LOCATION': 4, 'B-NAME': 5, 'B-ORGANIZATION': 6, 'B-PATIENT_ID': 7, 'B-SYMPTOM_AND_DISEASE': 8, 'B-TRANSPORTATION': 9, 'I-AGE': 10, 'I-DATE': 11, 'I-JOB': 12, 'I-LOCATION': 13, 'I-NAME': 14, 'I-ORGANIZATION': 15, 'I-PATIENT_ID': 16, 'I-SYMPTOM_AND_DISEASE': 17, 'I-TRANSPORTATION': 18, 'O': 19, '<pad_tag>': -100}
# Loading data from: /kaggle/input/phoner/phoner/train_word.json
# File /kaggle/input/phoner/phoner/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Loading data from: /kaggle/input/phoner/phoner/dev_word.json
# File /kaggle/input/phoner/phoner/dev_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 06:16:59 - INFO - Initializing Transformer Model for NER...
# 06:17:01 - INFO - Start Training...
# 06:18:21 - INFO - Epoch 1/15 | Train Loss: 1.0765 | Val Loss: 0.6167 | Acc: 0.8200 | F1: 0.7810 [BEST SAVED]
# 06:19:40 - INFO - Epoch 2/15 | Train Loss: 0.5428 | Val Loss: 0.3811 | Acc: 0.8825 | F1: 0.8759 [BEST SAVED]
# 06:21:01 - INFO - Epoch 3/15 | Train Loss: 0.4088 | Val Loss: 0.3087 | Acc: 0.9036 | F1: 0.9008 [BEST SAVED]
# 06:22:20 - INFO - Epoch 4/15 | Train Loss: 0.3340 | Val Loss: 0.2717 | Acc: 0.9206 | F1: 0.9169 [BEST SAVED]
# 06:23:41 - INFO - Epoch 5/15 | Train Loss: 0.2897 | Val Loss: 0.2308 | Acc: 0.9299 | F1: 0.9282 [BEST SAVED]
# 06:25:01 - INFO - Epoch 6/15 | Train Loss: 0.2566 | Val Loss: 0.2264 | Acc: 0.9359 | F1: 0.9339 [BEST SAVED]
# 06:26:22 - INFO - Epoch 7/15 | Train Loss: 0.2307 | Val Loss: 0.2188 | Acc: 0.9408 | F1: 0.9393 [BEST SAVED]
# 06:27:42 - INFO - Epoch 8/15 | Train Loss: 0.2103 | Val Loss: 0.2095 | Acc: 0.9439 | F1: 0.9428 [BEST SAVED]
# 06:29:01 - INFO - Epoch 9/15 | Train Loss: 0.1945 | Val Loss: 0.2109 | Acc: 0.9450 | F1: 0.9441 [BEST SAVED]
# 06:30:22 - INFO - Epoch 10/15 | Train Loss: 0.1818 | Val Loss: 0.2137 | Acc: 0.9484 | F1: 0.9468 [BEST SAVED]
# 06:31:42 - INFO - Epoch 11/15 | Train Loss: 0.1723 | Val Loss: 0.2101 | Acc: 0.9493 | F1: 0.9482 [BEST SAVED]
# 06:33:01 - INFO - Epoch 12/15 | Train Loss: 0.1600 | Val Loss: 0.2049 | Acc: 0.9515 | F1: 0.9502 [BEST SAVED]
# 06:34:22 - INFO - Epoch 13/15 | Train Loss: 0.1550 | Val Loss: 0.2127 | Acc: 0.9521 | F1: 0.9512 [BEST SAVED]
# 06:35:43 - INFO - Epoch 14/15 | Train Loss: 0.1462 | Val Loss: 0.2218 | Acc: 0.9529 | F1: 0.9518 [BEST SAVED]
# 06:37:03 - INFO - Epoch 15/15 | Train Loss: 0.1399 | Val Loss: 0.2268 | Acc: 0.9534 | F1: 0.9524 [BEST SAVED]
# 06:37:03 - INFO - Evaluating on Test Set...
# 06:37:03 - INFO - Loaded best model.
# Loading data from: /kaggle/input/phoner/phoner/test_word.json
# File /kaggle/input/phoner/phoner/test_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 06:37:15 - INFO - TEST | Loss: 0.2687 | Acc: 0.9480 | F1: 0.9462
#
# Classification Report:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                        precision    recall  f1-score   support
#
#                 B-AGE       0.89      0.93      0.91       582
#                B-DATE       0.95      0.96      0.96      1654
#              B-GENDER       0.89      0.94      0.92       462
#                 B-JOB       0.74      0.49      0.59       173
#            B-LOCATION       0.85      0.89      0.87      4441
#                B-NAME       0.89      0.55      0.68       318
#        B-ORGANIZATION       0.87      0.79      0.82       771
#          B-PATIENT_ID       0.90      0.94      0.92      2005
# B-SYMPTOM_AND_DISEASE       0.90      0.81      0.85      1136
#      B-TRANSPORTATION       0.93      0.75      0.83       193
#                 I-AGE       0.00      0.00      0.00         6
#                I-DATE       0.95      0.98      0.96      1750
#                 I-JOB       0.53      0.15      0.23       114
#            I-LOCATION       0.89      0.81      0.85      4918
#                I-NAME       1.00      0.08      0.14        13
#        I-ORGANIZATION       0.90      0.77      0.83      2014
#          I-PATIENT_ID       0.00      0.00      0.00        27
# I-SYMPTOM_AND_DISEASE       0.87      0.72      0.79      1486
#      I-TRANSPORTATION       0.96      0.39      0.56        69
#                     O       0.97      0.98      0.98     63546
#
#              accuracy                           0.95     85678
#             macro avg       0.79      0.65      0.68     85678
#          weighted avg       0.95      0.95      0.95     85678
