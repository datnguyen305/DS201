# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lab5-dataset/lab5/dev.json
# /kaggle/input/lab5-dataset/lab5/train.json
# /kaggle/input/lab5-dataset/lab5/test.json

# %%
# !git clone https://github.com/datnguyen305/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 560, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 560 (delta 65), reused 85 (delta 40), pack-reused 415 (from 1)
# Receiving objects: 100% (560/560), 68.74 MiB | 37.30 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
# %cd DS201/BT5
# Out:
# /kaggle/working/DS201/BT5

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 74.2 MB/s eta 0:00:00:00:010:01
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.2 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.12 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %%
# !python bai1_main.py
# Out:
# 05:25:13 - INFO - Using device: cpu
# 05:25:13 - INFO - Model Config: d_model=256, layers=3, heads=4
# 05:25:13 - INFO - Building Vocabulary...
# 05:25:17 - INFO - Vocab Size: 3140 tokens
# 05:25:17 - INFO - Labels (4): {'app': 0, 'cosmetic': 1, 'fashion': 2, 'mobile': 3}
# 05:25:20 - INFO - Loaded 4350 samples from /kaggle/input/lab5-dataset/lab5/train.json. Skipped 37 short/empty samples.
# 05:25:20 - INFO - Loaded 545 samples from /kaggle/input/lab5-dataset/lab5/dev.json. Skipped 3 short/empty samples.
# 05:25:20 - INFO - Initializing Transformer Model (Base)...
# 05:25:25 - INFO - Start Training...
# 05:28:33 - INFO - Epoch 1/30 | Train Loss: 1.3492 | Val Loss: 1.0955 | Acc: 0.2679 | F1: 0.2400 [BEST MODEL SAVED]
# 05:31:39 - INFO - Epoch 2/30 | Train Loss: 1.2384 | Val Loss: 1.0267 | Acc: 0.3633 | F1: 0.3201 [BEST MODEL SAVED]
# 05:34:50 - INFO - Epoch 3/30 | Train Loss: 1.1528 | Val Loss: 0.8969 | Acc: 0.4239 | F1: 0.3679 [BEST MODEL SAVED]
# 05:38:00 - INFO - Epoch 4/30 | Train Loss: 1.0754 | Val Loss: 0.9299 | Acc: 0.4771 | F1: 0.3731 [BEST MODEL SAVED]
# 05:41:10 - INFO - Epoch 5/30 | Train Loss: 0.9381 | Val Loss: 0.7484 | Acc: 0.5211 | F1: 0.4194 [BEST MODEL SAVED]
# 05:44:18 - INFO - Epoch 6/30 | Train Loss: 0.8799 | Val Loss: 0.7812 | Acc: 0.5083 | F1: 0.4051
# 05:47:29 - INFO - Epoch 7/30 | Train Loss: 0.8270 | Val Loss: 0.7698 | Acc: 0.5138 | F1: 0.4055
# 05:50:37 - INFO - Epoch 8/30 | Train Loss: 0.8213 | Val Loss: 0.8444 | Acc: 0.5193 | F1: 0.4023
# 05:53:49 - INFO - Epoch 9/30 | Train Loss: 0.7526 | Val Loss: 0.7871 | Acc: 0.5193 | F1: 0.4074
# 05:57:01 - INFO - Epoch 10/30 | Train Loss: 0.7248 | Val Loss: 0.7731 | Acc: 0.5156 | F1: 0.4103
# 06:00:05 - INFO - Epoch 11/30 | Train Loss: 0.7104 | Val Loss: 0.7533 | Acc: 0.5174 | F1: 0.4175
# 06:03:15 - INFO - Epoch 12/30 | Train Loss: 0.6918 | Val Loss: 0.8321 | Acc: 0.5046 | F1: 0.4148
# 06:06:20 - INFO - Epoch 13/30 | Train Loss: 0.6782 | Val Loss: 1.0037 | Acc: 0.5229 | F1: 0.4230 [BEST MODEL SAVED]
# 06:09:33 - INFO - Epoch 14/30 | Train Loss: 0.6852 | Val Loss: 0.8139 | Acc: 0.5138 | F1: 0.4196
# Epoch 15 - Training:  65%|▋| 44/68 [01:51<00:54,  2.25s/it, loss=0.6476, lr=0.00^C
# Traceback (most recent call last):
#   File "/kaggle/working/DS201/BT5/bai1_main.py", line 224, in <module>
#     main()
#   File "/kaggle/working/DS201/BT5/bai1_main.py", line 181, in main
#     train_loss = train(model, train_loader, optimizer, epoch)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/DS201/BT5/bai1_main.py", line 87, in train
#     _, loss = model(input_ids, label_ids)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/DS201/BT5/model/classification.py", line 43, in forward
#     features = self.encoder(features, attention_mask)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/DS201/BT5/model/transformer.py", line 101, in forward
#     outputs = layer(outputs, attention_mask)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/DS201/BT5/model/transformer.py", line 80, in forward
#     out = self.self_attn(src, src, src, attention_mask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/DS201/BT5/model/transformer.py", line 24, in forward
#     q = self.fc_q(queries).view(b_s, nq, self.head, self.d_q).permute(0, 2, 1, 3)  # b_s, head, nq, d_q
#         ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py", line 125, in forward
#     return F.linear(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
