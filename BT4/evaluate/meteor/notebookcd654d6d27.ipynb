# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !rm -rf DS201

# %%
# !git clone https://github.com/datnguyen305/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 196 (delta 68), reused 142 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (196/196), 9.57 MiB | 39.06 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd DS201/BT4
# Out:
# /kaggle/working/DS201/BT4

# %%
# !ls
# Out:
# assignments.ipynb  dataset.py  LSTM_main.py  preprocess_data.ipynb
# config		   evaluate    models	     vocab.py

# %%
# !apt-get install default-jre

# %%
# !python LSTM_main.py
# Out:
# Loading vocab ...
# Creating model ...
# Loading dataset ...
# Starting training ...
# Epoch 0 Training: 100%|██████████| 157/157 [01:34<00:00,  1.67it/s, loss=5.8241]
# {'testlen': 51578, 'reflen': 44311, 'guess': [51578, 49578, 47578, 45578], 'correct': [8424, 1550, 8, 2]}
# ratio: 1.163999909728935
#
# --- Epoch 01 Complete (Time: 2m 38s) ---
# Training Loss: 6.1287 | Dev Loss: 6.4051
# ⭐️ Dev BLEU-4 Score: 0.25%
#   >>> SAVED: New best model found! (BLEU-4: 0.25%)
# Epoch 1 Training: 100%|██████████| 157/157 [01:33<00:00,  1.69it/s, loss=5.7066]
# {'testlen': 44860, 'reflen': 44311, 'guess': [44860, 42860, 40860, 38860], 'correct': [9132, 2086, 9, 2]}
# ratio: 1.0123897000744508
#
# --- Epoch 02 Complete (Time: 2m 34s) ---
# Training Loss: 5.8007 | Dev Loss: 6.1841
# ⭐️ Dev BLEU-4 Score: 0.33%
#   >>> SAVED: New best model found! (BLEU-4: 0.33%)
# Epoch 2 Training: 100%|██████████| 157/157 [01:32<00:00,  1.70it/s, loss=5.7420]
# {'testlen': 48072, 'reflen': 44311, 'guess': [48072, 46072, 44072, 42072], 'correct': [9395, 2232, 48, 18]}
# ratio: 1.0848773442260142
#
# --- Epoch 03 Complete (Time: 2m 34s) ---
# Training Loss: 5.6962 | Dev Loss: 6.0831
# ⭐️ Dev BLEU-4 Score: 0.81%
#   >>> SAVED: New best model found! (BLEU-4: 0.81%)
# Epoch 3 Training: 100%|██████████| 157/157 [01:32<00:00,  1.70it/s, loss=5.6206]
# {'testlen': 49241, 'reflen': 44311, 'guess': [49241, 47241, 45241, 43241], 'correct': [10436, 2413, 52, 17]}
# ratio: 1.111259055313554
#
# --- Epoch 04 Complete (Time: 2m 35s) ---
# Training Loss: 5.6031 | Dev Loss: 6.0236
# ⭐️ Dev BLEU-4 Score: 0.84%
#   >>> SAVED: New best model found! (BLEU-4: 0.84%)
# Epoch 4 Training: 100%|██████████| 157/157 [01:32<00:00,  1.70it/s, loss=5.6090]
# {'testlen': 46010, 'reflen': 44311, 'guess': [46010, 44010, 42010, 40011], 'correct': [10364, 2384, 81, 25]}
# ratio: 1.0383426237277191
#
# --- Epoch 05 Complete (Time: 2m 33s) ---
# Training Loss: 5.5259 | Dev Loss: 6.0046
# ⭐️ Dev BLEU-4 Score: 1.10%
#   >>> SAVED: New best model found! (BLEU-4: 1.10%)
# Epoch 5 Training: 100%|██████████| 157/157 [01:31<00:00,  1.71it/s, loss=5.5390]
# {'testlen': 45180, 'reflen': 44311, 'guess': [45180, 43180, 41185, 39192], 'correct': [10137, 2505, 107, 19]}
# ratio: 1.019611383177969
#
# --- Epoch 06 Complete (Time: 2m 32s) ---
# Training Loss: 5.4521 | Dev Loss: 6.0022
# ⭐️ Dev BLEU-4 Score: 1.13%
#   >>> SAVED: New best model found! (BLEU-4: 1.13%)
# Epoch 6 Training: 100%|██████████| 157/157 [01:34<00:00,  1.67it/s, loss=5.2187]
# {'testlen': 43425, 'reflen': 44311, 'guess': [43425, 41425, 39431, 37437], 'correct': [10748, 2680, 154, 33]}
# ratio: 0.9800049649071116
#
# --- Epoch 07 Complete (Time: 2m 33s) ---
# Training Loss: 5.3765 | Dev Loss: 5.9592
# ⭐️ Dev BLEU-4 Score: 1.50%
#   >>> SAVED: New best model found! (BLEU-4: 1.50%)
# Epoch 7 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.2393]
# {'testlen': 46290, 'reflen': 44311, 'guess': [46290, 44290, 42291, 40292], 'correct': [11213, 2878, 186, 35]}
# ratio: 1.0446615964432975
#
# --- Epoch 08 Complete (Time: 2m 34s) ---
# Training Loss: 5.3051 | Dev Loss: 5.9295
# ⭐️ Dev BLEU-4 Score: 1.57%
#   >>> SAVED: New best model found! (BLEU-4: 1.57%)
# Epoch 8 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.9929]
# {'testlen': 40432, 'reflen': 44311, 'guess': [40432, 38432, 36433, 34434], 'correct': [13623, 2847, 291, 62]}
# ratio: 0.9124596601295184
#
# --- Epoch 09 Complete (Time: 2m 31s) ---
# Training Loss: 5.1094 | Dev Loss: 5.6220
# ⭐️ Dev BLEU-4 Score: 2.22%
#   >>> SAVED: New best model found! (BLEU-4: 2.22%)
# Epoch 9 Training: 100%|██████████| 157/157 [01:32<00:00,  1.69it/s, loss=4.8164]
# {'testlen': 43130, 'reflen': 44311, 'guess': [43130, 41130, 39130, 37131], 'correct': [13471, 3219, 397, 88]}
# ratio: 0.9733474757960558
#
# --- Epoch 10 Complete (Time: 2m 32s) ---
# Training Loss: 4.7281 | Dev Loss: 5.3968
# ⭐️ Dev BLEU-4 Score: 2.69%
#   >>> SAVED: New best model found! (BLEU-4: 2.69%)
# Epoch 10 Training: 100%|█████████| 157/157 [01:32<00:00,  1.70it/s, loss=4.4102]
# {'testlen': 44303, 'reflen': 44311, 'guess': [44303, 42303, 40304, 38305], 'correct': [14252, 3739, 466, 115]}
# ratio: 0.9998194579223896
#
# --- Epoch 11 Complete (Time: 2m 32s) ---
# Training Loss: 4.4727 | Dev Loss: 5.3012
# ⭐️ Dev BLEU-4 Score: 3.15%
#   >>> SAVED: New best model found! (BLEU-4: 3.15%)
# Epoch 11 Training: 100%|█████████| 157/157 [01:32<00:00,  1.70it/s, loss=3.9731]
# {'testlen': 46631, 'reflen': 44311, 'guess': [46631, 44631, 42631, 40631], 'correct': [14812, 4131, 545, 150]}
# ratio: 1.0523572025004841
#
# --- Epoch 12 Complete (Time: 2m 33s) ---
# Training Loss: 4.2835 | Dev Loss: 5.2395
# ⭐️ Dev BLEU-4 Score: 3.43%
#   >>> SAVED: New best model found! (BLEU-4: 3.43%)
# Epoch 12 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.2973]
# {'testlen': 44870, 'reflen': 44311, 'guess': [44870, 42870, 40870, 38870], 'correct': [14861, 4201, 582, 159]}
# ratio: 1.0126153776714357
#
# --- Epoch 13 Complete (Time: 2m 33s) ---
# Training Loss: 4.1387 | Dev Loss: 5.2130
# ⭐️ Dev BLEU-4 Score: 3.71%
#   >>> SAVED: New best model found! (BLEU-4: 3.71%)
# Epoch 13 Training: 100%|█████████| 157/157 [01:33<00:00,  1.67it/s, loss=4.0242]
# {'testlen': 45961, 'reflen': 44311, 'guess': [45961, 43961, 41961, 39961], 'correct': [14894, 4327, 658, 196]}
# ratio: 1.037236803502493
#
# --- Epoch 14 Complete (Time: 2m 35s) ---
# Training Loss: 4.0126 | Dev Loss: 5.2082
# ⭐️ Dev BLEU-4 Score: 3.96%
#   >>> SAVED: New best model found! (BLEU-4: 3.96%)
# Epoch 14 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=3.9935]
# {'testlen': 45009, 'reflen': 44311, 'guess': [45009, 43009, 41009, 39009], 'correct': [15055, 4333, 665, 195]}
# ratio: 1.0157522962695265
#
# --- Epoch 15 Complete (Time: 2m 34s) ---
# Training Loss: 3.8947 | Dev Loss: 5.2031
# ⭐️ Dev BLEU-4 Score: 4.07%
#   >>> SAVED: New best model found! (BLEU-4: 4.07%)
# Epoch 15 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.1080]
# {'testlen': 45222, 'reflen': 44311, 'guess': [45222, 43222, 41222, 39222], 'correct': [15197, 4476, 705, 208]}
# ratio: 1.0205592290853058
#
# --- Epoch 16 Complete (Time: 2m 33s) ---
# Training Loss: 3.7890 | Dev Loss: 5.2150
# ⭐️ Dev BLEU-4 Score: 4.21%
#   >>> SAVED: New best model found! (BLEU-4: 4.21%)
# Epoch 16 Training: 100%|█████████| 157/157 [01:32<00:00,  1.70it/s, loss=3.7390]
# {'testlen': 45976, 'reflen': 44311, 'guess': [45976, 43976, 41976, 39976], 'correct': [15058, 4448, 736, 215]}
# ratio: 1.0375753198979705
#
# --- Epoch 17 Complete (Time: 2m 33s) ---
# Training Loss: 3.6868 | Dev Loss: 5.2184
# ⭐️ Dev BLEU-4 Score: 4.20%
#   >>> No improvement in BLEU. Patience: 1/5
# Epoch 17 Training: 100%|█████████| 157/157 [01:33<00:00,  1.67it/s, loss=3.7197]
# {'testlen': 46404, 'reflen': 44311, 'guess': [46404, 44404, 42404, 40404], 'correct': [15144, 4528, 772, 230]}
# ratio: 1.0472343210489259
#
# --- Epoch 18 Complete (Time: 2m 34s) ---
# Training Loss: 3.5923 | Dev Loss: 5.2400
# ⭐️ Dev BLEU-4 Score: 4.31%
#   >>> SAVED: New best model found! (BLEU-4: 4.31%)
# Epoch 18 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=3.6987]
# {'testlen': 47198, 'reflen': 44311, 'guess': [47198, 45198, 43198, 41198], 'correct': [15151, 4578, 800, 247]}
# ratio: 1.0651531222495303
#
# --- Epoch 19 Complete (Time: 2m 34s) ---
# Training Loss: 3.4985 | Dev Loss: 5.2819
# ⭐️ Dev BLEU-4 Score: 4.36%
#   >>> SAVED: New best model found! (BLEU-4: 4.36%)
# Epoch 19 Training: 100%|█████████| 157/157 [01:33<00:00,  1.69it/s, loss=3.4829]
# {'testlen': 45500, 'reflen': 44311, 'guess': [45500, 43500, 41500, 39500], 'correct': [15007, 4545, 775, 235]}
# ratio: 1.026833066281487
#
# --- Epoch 20 Complete (Time: 2m 33s) ---
# Training Loss: 3.4101 | Dev Loss: 5.2899
# ⭐️ Dev BLEU-4 Score: 4.42%
#   >>> SAVED: New best model found! (BLEU-4: 4.42%)
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
# {'testlen': 51680, 'reflen': 49513, 'guess': [51680, 49680, 47680, 45680], 'correct': [16587, 4972, 877, 277]}
# ratio: 1.0437662836022652
# Skipping METEOR due to error: [Errno 32] Broken pipe
# ^C
# Exception ignored in: <function Meteor.__del__ at 0x7cb35ddde8e0>
# Traceback (most recent call last):
#   File "/kaggle/working/DS201/BT4/evaluate/meteor/meteor.py", line 78, in __del__
#     self.lock.acquire()
# KeyboardInterrupt:
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.2080
# BLEU-4 Score: 4.35%
# ROUGE-L Score: 32.79%
# METEOR Score: 0.00%
